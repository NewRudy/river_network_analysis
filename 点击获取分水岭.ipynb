# %%
# Read elevation raster
# ----------------------------
from pysheds.grid import Grid
import numpy as np

grid = Grid.from_raster("./dem/测试数据对比/pysheds数据/test.tif")
dem = grid.read_raster("./dem/测试数据对比/pysheds数据/test.tif")

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import seaborn as sns

fig, ax = plt.subplots(figsize=(8, 6))
fig.patch.set_alpha(0)

plt.imshow(dem, extent=grid.extent, cmap="terrain", zorder=1)
plt.colorbar(label="Elevation (m)")
plt.grid(zorder=0)
plt.title("Digital elevation map", size=14)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.tight_layout()

# %%
# Condition DEM
# ----------------------
# Fill pits in DEM
pit_filled_dem = grid.fill_pits(dem)

# Fill depressions in DEM
# TODO: I don't know why the result is warning!
flooded_dem = grid.fill_depressions(pit_filled_dem)

# Resolve flats in DEM
inflated_dem = grid.resolve_flats(pit_filled_dem)

# %%
# grid.to_raster(
#     pit_filled_dem,
#     "./dem/测试数据对比/pysheds数据/pit_filled_dem.tif",
#     apply_output_mask=True,
#     blockxsize=16,
#     blockysize=16,
# )
grid.to_raster(
    flooded_dem,
    "./dem/测试数据对比/pysheds数据/flooded_dem.tif",
    apply_output_mask=True,
    blockxsize=16,
    blockysize=16,
)
grid.to_raster(
    inflated_dem,
    "./dem/测试数据对比/pysheds数据/inflated_dem.tif",
    apply_output_mask=True,
    blockxsize=16,
    blockysize=16,
)

# %%
# Determine D8 flow directions from DEM
# ----------------------
# Specify directional mapping
dirmap = (64, 128, 1, 2, 4, 8, 16, 32)

# Compute flow directions
# -------------------------------------
fdir = grid.flowdir(pit_filled_dem, dirmap=dirmap)

grid.to_raster(
    fdir,
    "./dem/测试数据对比/pysheds数据/fdir.tif",
    apply_output_mask=True,
    blockxsize=16,
    blockysize=16,
)

# %%
fig = plt.figure(figsize=(8, 6))
fig.patch.set_alpha(0)

plt.imshow(fdir, extent=grid.extent, cmap="viridis", zorder=2)
boundaries = [0] + sorted(list(dirmap))
plt.colorbar(boundaries=boundaries, values=sorted(dirmap))
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Flow direction grid", size=14)
plt.grid(zorder=-1)
plt.tight_layout()

# %%
# Calculate flow accumulation
# --------------------------
acc = grid.accumulation(fdir, dirmap=dirmap)
grid.to_raster(
    acc,
    "./dem/测试数据对比/pysheds数据/acc.tif",
    apply_output_mask=True,
    blockxsize=16,
    blockysize=16,
)

# %%
fig, ax = plt.subplots(figsize=(8, 6))
fig.patch.set_alpha(0)
plt.grid("on", zorder=0)
im = ax.imshow(
    acc,
    extent=grid.extent,
    zorder=2,
    cmap="cubehelix",
    norm=colors.LogNorm(1, acc.max()),
    interpolation="bilinear",
)
plt.colorbar(im, ax=ax, label="Upstream Cells")
plt.title("Flow Accumulation", size=14)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.tight_layout()

# %%
import fiona

# Delineate a catchment
# ---------------------
# Specify pour point
# 测试三个出水口
# x, y = 106.60720301, 27.04004687
# x, y = 106.65132150, 26.99176978
x, y = 106.76655233, 26.94516790

# Snap pour point to high accumulation cell
x_snap, y_snap = grid.snap_to_mask(acc > 500, (x, y))

# Delineate the catchment
catch = grid.catchment(
    x=x_snap, y=y_snap, fdir=fdir, dirmap=dirmap, xytype="coordinate"
)

# Crop and plot the catchment
# ---------------------------
# Clip the bounding box to the catchment
grid.clip_to(catch)
clipped_catch = grid.view(catch)

clipped_catch_temp = grid.view(catch, dtype=np.uint8)

# Create a vector representation of the catchment mask
shapes = grid.polygonize(clipped_catch_temp)

# Specify schema
schema = {"geometry": "Polygon", "properties": {"LABEL": "float:16"}}

# Write shapefile
with fiona.open(
    "./dem/测试数据对比/pysheds数据/集水区/测试集水区3.shp",
    "w",
    driver="ESRI Shapefile",
    crs=grid.crs.srs,
    schema=schema,
) as c:
    i = 0
    for shape, value in shapes:
        rec = {}
        rec["geometry"] = shape
        rec["properties"] = {"LABEL": str(value)}
        rec["id"] = str(i)
        c.write(rec)
        i += 1

# %%
# x, y = 106.60720301, 27.04004687

# Reset the view
grid.viewfinder = fdir.viewfinder

# Find the row and column index corresponding to the pour point
# col, row = 542, 175
# col, row = 878, 616
col, row = 1781, 1061

# Delineate the catchment
catch = grid.catchment(x=col, y=row, fdir=fdir, xytype="index")

# Plot the result
grid.clip_to(catch)
clipped_catch = grid.view(catch)

clipped_catch_temp = grid.view(catch, dtype=np.uint8)

# Create a vector representation of the catchment mask
shapes = grid.polygonize(clipped_catch_temp)

# Specify schema
schema = {"geometry": "Polygon", "properties": {"LABEL": "float:16"}}

# Write shapefile
with fiona.open(
    "./dem/测试数据对比/pysheds数据/集水区/行列测试集水区3.shp",
    "w",
    driver="ESRI Shapefile",
    crs=grid.crs.srs,
    schema=schema,
) as c:
    i = 0
    for shape, value in shapes:
        rec = {}
        rec["geometry"] = shape
        rec["properties"] = {"LABEL": str(value)}
        rec["id"] = str(i)
        c.write(rec)
        i += 1

# %%
# Plot the catchment
fig, ax = plt.subplots(figsize=(8, 6))
fig.patch.set_alpha(0)

plt.grid("on", zorder=0)
im = ax.imshow(
    np.where(clipped_catch, clipped_catch, np.nan),
    extent=grid.extent,
    zorder=1,
    cmap="Greys_r",
)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Delineated Catchment", size=14)
# Out:
# Text(0.5, 1.0, 'Delineated Catchment')

# %%
# Extract river network
# ---------------------
branches = grid.extract_river_network(fdir, acc > 0, dirmap=dirmap)

# 定义 schema
schema = {
    "geometry": "LineString",  # 根据你的特征集合中的几何类型来定义
}

# 写入 Shapefile
with fiona.open(
    "./dem/测试数据对比/pysheds数据/集水区/行列测试集水区河网3_0.shp",
    "w",
    driver="ESRI Shapefile",
    crs=grid.crs.srs,
    schema=schema,
) as output:
    # 写入特征集合中的每个特征
    for feature in branches["features"]:
        output.write(
            feature
        )

# %%
sns.set_palette("husl")
fig, ax = plt.subplots(figsize=(8.5, 6.5))

plt.xlim(grid.bbox[0], grid.bbox[2])
plt.ylim(grid.bbox[1], grid.bbox[3])
ax.set_aspect("equal")

for branch in branches["features"]:
    line = np.asarray(branch["geometry"]["coordinates"])
    plt.plot(line[:, 0], line[:, 1])

_ = plt.title("D8 channels", size=14)

# %%
# Convert catchment raster to vector
# Read soils shapefile
import pandas as pd
import geopandas as gpd
from shapely import geometry, ops

# Convert catchment raster to vector geometry and find intersection
shapes = grid.polygonize()
catchment_polygon = ops.unary_union([geometry.shape(shape) for shape, value in shapes])
gdf = gpd.GeoDataFrame(geometry=[catchment_polygon])
gdf.to_file('./dem/测试数据对比/pysheds数据/集水区/集水区.shp')

# %%
# Convert catchment raster to vector
# Read soils shapefile
import pandas as pd
import geopandas as gpd
from shapely import geometry, ops

# Convert catchment raster to vector geometry and find intersection
shapes = branches.polygonize()
catchment_polygon = ops.unary_union([geometry.shape(shape) for shape, value in shapes])
gdf = gpd.GeoDataFrame(geometry=[catchment_polygon])
gdf.to_file("./dem/测试数据对比/pysheds数据/集水区/集水区.shp")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\geojson\feature.py:59, in FeatureCollection.__getitem__(self, key)
#      58 try:
# ---> 59     return self.get("features", ())[key]
#      60 except (KeyError, TypeError, IndexError):
#
# TypeError: list indices must be integers or slices, not str
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\geojson\base.py:38, in GeoJSON.__getattr__(self, name)
#      37 try:
# ---> 38     return self[name]
#      39 except KeyError:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\geojson\feature.py:61, in FeatureCollection.__getitem__(self, key)
#      60 except (KeyError, TypeError, IndexError):
# ---> 61     return super(GeoJSON, self).__getitem__(key)
#
# KeyError: 'polygonize'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 8
#       5 from shapely import geometry, ops
#       7 # Convert catchment raster to vector geometry and find intersection
# ----> 8 shapes = branches.polygonize()
#       9 catchment_polygon = ops.unary_union([geometry.shape(shape) for shape, value in shapes])
#      10 gdf = gpd.GeoDataFrame(geometry=[catchment_polygon])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\geojson\base.py:40, in GeoJSON.__getattr__(self, name)
#      38     return self[name]
#      39 except KeyError:
# ---> 40     raise AttributeError(name)
#
# AttributeError: polygonize
